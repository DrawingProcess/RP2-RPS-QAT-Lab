# %% [markdown]
# # RPS Classification에 QAT 적용

# %% [markdown]
# ## 설명 노트
#
# 각 코드 셀에 주석을 추가한 버전입니다.
#
# - 인식 대상: 가위(scissors), 바위(rock), 보(paper)
# - 사용 모델: `DenseNet121`
# - 입력 크기: `64 x 64 x 3` 컬러 이미지
# - 핵심 기법: 데이터 보강(Augmentation) + QAT(Quantization Aware Training) + TFLite 변환
# - 최종 산출물: `RPS_PreTrained_DenseNet_Augmentation_QAT.tflite`
#
# 라즈베리파이에서는 최종 `.tflite` 파일을 사용해 카메라 손 모양을 가위/바위/보로 분류할 수 있습니다.

# %% [markdown]
# ## Install TensorFlow Model Optimization Toolkit
# * 설치 완료 후 반드시 Runtime 재시작!
#     * '런타임' > '세션 다시 시작' 메뉴 선택'

# %%
# 필요한 패키지 설치
# Colab, GCP GPU 서버, VSCode Jupyter 모두에서 실행할 수 있게 작성했습니다.
#
# tensorflow-model-optimization: QAT 적용용
# opencv-python-headless: 서버 환경에서 이미지 읽기용. GUI 창이 필요 없으므로 headless 버전을 권장합니다.
# scikit-learn: train/test split용

import sys
import subprocess

required_packages = [
    "tensorflow-model-optimization",
    "opencv-python-headless",
    "scikit-learn",
]

subprocess.run([
    sys.executable, "-m", "pip", "install", "-q",
    *required_packages
], check=True)

print("Package installation/check complete.")
# Out:
# Package installation/check complete.

# %% [markdown]
# ## 모듈 로딩

# %%
# 기본 라이브러리 불러오기
# numpy: 배열 계산
# tensorflow/keras: 딥러닝 모델 생성과 학습
# matplotlib: 결과 그래프와 이미지 확인
# glob: 폴더 안 파일 목록 읽기
# cv2(OpenCV): 이미지 읽기, 색상 변환, 크기 변경
# train_test_split: 학습용/테스트용 데이터 분리
# tfmot: TensorFlow 모델 경량화와 QAT 적용
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import cv2
from sklearn.model_selection import train_test_split
import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.python.core.keras.compat import keras

# 현재 실행 환경의 주요 라이브러리 버전을 확인합니다.
# 버전 차이 때문에 QAT API가 다르게 동작할 수 있어 처음에 확인하는 것이 좋습니다.
print("NumPy Version :{}".format(np.__version__))
print("TensorFlow Version :{}".format(tf.__version__))
print("Matplotlib Version :{}".format(plt.matplotlib.__version__))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780891283.581830 3293545 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# NumPy Version :2.4.6
# TensorFlow Version :2.21.0
# Matplotlib Version :3.10.9

# %% [markdown]
# ### 실행 환경 확인
#
# 이 학생용 저장소는 `RPS_Dataset` 폴더를 저장소 안에 포함합니다.
# 따라서 Google Drive를 연결하지 않아도 Colab, GCP GPU 서버, VSCode에서 같은 방식으로 실행할 수 있습니다.

# %%
# Colab인지, GCP/VSCode 같은 일반 Python 환경인지 확인합니다.
# 데이터셋은 다음 셀에서 저장소 내부의 RPS_Dataset 폴더를 자동으로 찾습니다.
try:
    import google.colab  # type: ignore
    colab = True
    print("Colab environment.")
except Exception:
    colab = False
    print("Local/GCP/VSCode environment.")
# Out:
# Local/GCP/VSCode environment.

# %% [markdown]
# ### RPS 데이터셋 준비

# %%
# RPS 데이터셋 경로 설정
# 이 학생용 저장소는 구조가 단순합니다.
#
# RP2-RPS-QAT-Lab/
#   RPS_Dataset/
#   notebooks/
#
# 따라서 학생이 이 저장소를 fork/clone했다면 별도 다운로드 없이 RPS_Dataset을 바로 사용합니다.

import subprocess
from pathlib import Path

# 데이터셋이 포함된 학생용 실습 저장소입니다.
# 자기 fork 저장소를 자동 clone 대상으로 쓰고 싶으면 아래 URL만 바꾸면 됩니다.
# 예: "https://github.com/학생아이디/RP2-RPS-QAT-Lab.git"
GITHUB_REPO_URL = "https://github.com/philipdekim-OnD01/RP2-RPS-QAT-Lab.git"

COLAB_REPO_DIR = Path("/content/RP2-RPS-QAT-Lab")
SERVER_REPO_DIR = Path.home() / "RP2-RPS-QAT-Lab_data"


def get_git_root():
    """현재 노트북이 Git 저장소 안에서 실행 중이면 저장소 루트 경로를 반환합니다."""
    try:
        result = subprocess.run(
            ["git", "rev-parse", "--show-toplevel"],
            check=True,
            capture_output=True,
            text=True,
        )
        return Path(result.stdout.strip())
    except Exception:
        return None


def clone_repo_if_needed(target_dir):
    """데이터셋이 없을 때 학생용 GitHub 저장소를 clone합니다."""
    if not target_dir.exists():
        print("Clone GitHub repository for RPS_Dataset:", GITHUB_REPO_URL)
        subprocess.run([
            "git", "clone", "--depth", "1",
            GITHUB_REPO_URL,
            str(target_dir)
        ], check=True)
    else:
        print("Repository already exists:", target_dir)
    return target_dir


candidate_paths = []

# 1) VSCode에서 fork 저장소 폴더를 열고 실행하면 이 경로가 가장 안정적입니다.
git_root = get_git_root()
if git_root is not None:
    candidate_paths.append(git_root / "RPS_Dataset")

# 2) 노트북 실행 위치가 notebooks/이거나 저장소 루트일 때 가능한 경로들입니다.
cwd = Path.cwd()
candidate_paths.extend([
    cwd / "RPS_Dataset",
    cwd / "../RPS_Dataset",
    Path("RPS_Dataset"),
    Path("../RPS_Dataset"),
])

files_path = None
for candidate in candidate_paths:
    candidate = candidate.resolve()
    if candidate.exists() and candidate.is_dir():
        files_path = str(candidate)
        break

# 3) 그래도 못 찾으면 GitHub에서 학생용 저장소를 clone해서 데이터를 준비합니다.
if files_path is None:
    clone_dir = COLAB_REPO_DIR if colab else SERVER_REPO_DIR
    repo_dir = clone_repo_if_needed(clone_dir)
    dataset_dir = repo_dir / "RPS_Dataset"
    if not dataset_dir.exists():
        raise FileNotFoundError(
            f"RPS_Dataset 폴더를 찾을 수 없습니다: {dataset_dir}. "
            "GITHUB_REPO_URL이 올바른지 확인하세요."
        )
    files_path = str(dataset_dir)

print("Working directory:", Path.cwd())
print("Git root:", git_root)
print("RPS dataset path:", files_path)
print("Class folders:", sorted([p.name for p in Path(files_path).iterdir() if p.is_dir()]))

# 폴더 구조
# RPS_Dataset/
#   0/  -> scissors, 가위
#   1/  -> rock, 바위
#   2/  -> paper, 보
# Out:
# Working directory: /SSD1/sjchoi/semiai/RP2-RPS-QAT-Lab/notebooks
# Git root: /SSD1/sjchoi/semiai/RP2-RPS-QAT-Lab
# RPS dataset path: /SSD1/sjchoi/semiai/RP2-RPS-QAT-Lab/RPS_Dataset
# Class folders: ['0', '1', '2']

# %% [markdown]
# ### 폴더 별로 파일 읽어 데이터화 진행

# %%
# %%time
# 이미지 파일을 읽어서 모델 학습에 사용할 numpy 배열로 만드는 단계입니다.
# 최종 모델 입력 크기는 64 x 64 x 3 입니다.
# 64 x 64: 이미지 크기
# 3: RGB 컬러 채널

first = True
IMG_SIZE = 64

# ind는 클래스 번호입니다.
# 0: scissors, 1: rock, 2: paper
for ind in range(0, 3, 1) :
    # 각 클래스 폴더 안의 모든 이미지 파일을 읽습니다.
    path = files_path + '/' + str(ind) + '/*.*'
    print(path)
    files = glob.glob(path)

    # 이미지 처리 흐름
    # 1) cv2.imread(): 이미지 파일 읽기. OpenCV는 BGR 순서로 읽습니다.
    # 2) cv2.cvtColor(..., COLOR_BGR2RGB): BGR을 RGB로 바꿉니다.
    # 3) cv2.resize(): 모든 이미지를 64 x 64로 맞춥니다.
    # 4) np.array(): 여러 장의 이미지를 하나의 배열로 묶습니다.
    tmpx = np.array([
        cv2.resize(
            cv2.cvtColor(cv2.imread(x, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB),
            (IMG_SIZE, IMG_SIZE)
        )
        for x in files
    ])

    # tmpy는 정답 라벨입니다.
    # 현재 폴더 번호 ind를 이미지 개수만큼 반복해서 라벨 배열을 만듭니다.
    tmpy = np.array([ind] * len(files))

    # 각 클래스별로 80%는 학습용, 20%는 테스트용으로 나눕니다.
    # random_state를 고정하면 매번 같은 방식으로 나뉘어 실험 결과 비교가 쉽습니다.
    xtrain, xtest, ytrain, ytest = train_test_split(
        tmpx, tmpy, test_size=0.2, random_state=123
    )

    # 첫 클래스는 배열을 새로 만들고,
    # 두 번째 클래스부터는 기존 배열 뒤에 이어 붙입니다.
    if first == True:
        train_data = xtrain.copy()
        train_labels = ytrain.copy()
        test_data = xtest.copy()
        test_labels = ytest.copy()
        first = False
    else :
        train_data = np.concatenate((train_data, xtrain))
        train_labels = np.concatenate((train_labels, ytrain))
        test_data = np.concatenate((test_data, xtest))
        test_labels = np.concatenate((test_labels, ytest))
# Out:
# /SSD1/sjchoi/semiai/RP2-RPS-QAT-Lab/RPS_Dataset/0/*.*
# /SSD1/sjchoi/semiai/RP2-RPS-QAT-Lab/RPS_Dataset/1/*.*
# /SSD1/sjchoi/semiai/RP2-RPS-QAT-Lab/RPS_Dataset/2/*.*
# CPU times: user 6.41 s, sys: 204 ms, total: 6.61 s
# Wall time: 6.61 s

# %% [markdown]
# ### 데이터 확인

# %%
# 데이터 모양(shape)을 확인합니다.
# 예상 형태:
# train_data   -> (학습 이미지 수, 64, 64, 3)
# train_labels -> (학습 라벨 수,)
# test_data    -> (테스트 이미지 수, 64, 64, 3)
# test_labels  -> (테스트 라벨 수,)

# DenseNet의 preprocess_input()에서 입력 전처리를 처리합니다.
# 그래서 여기서는 train_data / 255.0 같은 정규화를 하지 않습니다.
# train_data = train_data / 255.0
# test_data = test_data / 255.0

print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (2172, 64, 64, 3)
# (2172,)
# (545, 64, 64, 3)
# (545,)

# %% [markdown]
# ### ImageDataGenerator 객체 생성

# %%
# ImageDataGenerator는 학습 이미지를 매번 조금씩 변형해 주는 도구입니다.
# 목적: 실제 카메라 환경처럼 손 위치, 밝기, 각도, 크기가 달라져도 잘 맞히게 만들기
img_gen_train = tf.keras.preprocessing.image.ImageDataGenerator(
                horizontal_flip=True,         # 좌우 반전. 손 모양 방향이 바뀌는 상황 대응
                rotation_range=0.2,           # 이미지를 조금 회전. 손이 기울어진 상황 대응
                width_shift_range=0.1,        # 좌우 이동. 손이 중앙에서 벗어난 상황 대응
                height_shift_range=0.1,       # 상하 이동. 손 높이가 달라지는 상황 대응
                brightness_range=(0.1, 0.9),  # 밝기 변화. 조명이 어둡거나 밝은 상황 대응
                zoom_range=0.2                # 확대/축소. 카메라와 손 거리 변화 대응
                )

# flow()는 원본 train_data를 읽어, 학습 중에 변형된 이미지를 계속 공급합니다.
# seed를 고정하면 실험 재현성이 좋아집니다.
train_gen = img_gen_train.flow(train_data, train_labels, seed = 1)

# %% [markdown]
# ### 모델 생성

# %%
# 모델 생성 단계
# 이 코드는 ResNet이 아니라 DenseNet121을 사용합니다.
# DenseNet121은 ImageNet으로 미리 학습된 이미지 인식 모델입니다.
# 우리는 맨 뒤 분류기를 가위/바위/보 3개 클래스로 바꿔서 사용합니다.

# 입력 이미지는 64 x 64 RGB 이미지입니다.
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))

# DenseNet이 기대하는 방식으로 입력 이미지를 전처리합니다.
# 픽셀 스케일과 색상 기준을 DenseNet 학습 방식에 맞춥니다.
x = keras.applications.densenet.preprocess_input(inputs)

# ImageNet 사전학습 가중치를 가진 DenseNet121을 불러옵니다.
# include_top=False는 ImageNet용 1000개 클래스 분류 머리를 제거한다는 뜻입니다.
# input_tensor=x로 우리가 만든 입력과 전처리 흐름을 연결합니다.
base_model = keras.applications.DenseNet121(
    weights="imagenet",
    include_top=False,
    input_tensor = x
)

# BatchNormalization layer는 학습 중 통계가 흔들리면 전이학습 성능이 불안정할 수 있어 고정합니다.
# 나머지 layer는 trainable=True로 두어 RPS 데이터에 맞게 미세조정합니다.
for layer in base_model.layers:
    if isinstance(layer, keras.layers.BatchNormalization):
        layer.trainable = False
    else:
        layer.trainable = True

# DenseNet이 뽑은 특징맵을 하나의 벡터로 요약합니다.
x = base_model.output
x = keras.layers.GlobalAveragePooling2D()(x)

# Dropout은 과적합을 줄이기 위해 일부 뉴런을 학습 중 임의로 꺼 줍니다.
x = keras.layers.Dropout(0.2)(x)

# 최종 출력은 3개입니다.
# 0: scissors, 1: rock, 2: paper
outputs = keras.layers.Dense(3, activation='softmax')(x)

# 입력부터 출력까지 연결한 최종 모델입니다.
model = keras.Model(inputs, outputs)

# 모델 구조와 파라미터 수를 확인합니다.
model.summary()
# Out:
# W0000 00:00:1780891294.547959 3293654 cuda_executor.cc:1755] Failed to determine cuDNN version (Note that this is expected if the application doesn't link the cuDNN plugin): INTERNAL: cuDNN error: CUDNN_STATUS_INTERNAL_ERROR
# W0000 00:00:1780891294.694794 3293545 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 3s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  tf.math.truediv (TFOpLambd  (None, 64, 64, 3)            0         ['input_1[0][0]']
#  a)
#
#  tf.nn.bias_add (TFOpLambda  (None, 64, 64, 3)            0         ['tf.math.truediv[0][0]']
#  )
#
#  tf.math.truediv_1 (TFOpLam  (None, 64, 64, 3)            0         ['tf.nn.bias_add[0][0]']
#  bda)
#
#  zero_padding2d (ZeroPaddin  (None, 70, 70, 3)            0         ['tf.math.truediv_1[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 32, 32, 64)           9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 32, 32, 64)           256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 32, 32, 64)           0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 34, 34, 64)           0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 16, 16, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 16, 16, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 16, 16, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 16, 16, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 16, 16, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 16, 16, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 16, 16, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 16, 16, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 16, 16, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 16, 16, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 16, 16, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 16, 16, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 16, 16, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 16, 16, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 16, 16, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 16, 16, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 16, 16, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 16, 16, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 16, 16, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 16, 16, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 16, 16, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 16, 16, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 16, 16, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 16, 16, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 16, 16, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 16, 16, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 16, 16, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 16, 16, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 16, 16, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 16, 16, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 16, 16, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 16, 16, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 16, 16, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 16, 16, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 8, 8, 128)            0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 8, 8, 128)            512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 8, 8, 128)            16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 8, 8, 32)             36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 8, 8, 160)            0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 8, 8, 160)            640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 8, 8, 160)            0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 8, 8, 128)            20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 8, 8, 32)             36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 8, 8, 192)            0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 8, 8, 192)            768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 8, 8, 192)            0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 8, 8, 128)            24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 8, 8, 32)             36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 8, 8, 224)            0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 8, 8, 224)            896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 8, 8, 224)            0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 8, 8, 128)            28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 8, 8, 32)             36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 8, 8, 256)            0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 8, 8, 256)            0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 8, 8, 128)            32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 8, 8, 32)             36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 8, 8, 288)            0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 8, 8, 288)            1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 8, 8, 288)            0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 8, 8, 128)            36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 8, 8, 32)             36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 8, 8, 320)            0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 8, 8, 320)            1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 8, 8, 320)            0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 8, 8, 128)            40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 8, 8, 32)             36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 8, 8, 352)            0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 8, 8, 352)            1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 8, 8, 352)            0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 8, 8, 128)            45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 8, 8, 32)             36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 8, 8, 384)            0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 8, 8, 384)            1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 8, 8, 384)            0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 8, 8, 128)            49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 8, 8, 128)            512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 8, 8, 128)            0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 8, 8, 32)             36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 8, 8, 416)            0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 8, 8, 416)            1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 8, 8, 416)            0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 8, 8, 128)            53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 8, 8, 128)            0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 8, 8, 448)            0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 8, 8, 448)            1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 8, 8, 448)            0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 8, 8, 128)            57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 8, 8, 128)            0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 8, 8, 480)            0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 8, 8, 480)            1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 8, 8, 480)            0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 8, 8, 128)            61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 8, 8, 128)            0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 8, 8, 512)            0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 8, 8, 512)            2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 8, 8, 512)            0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 8, 8, 256)            131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 4, 4, 256)            0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 4, 4, 256)            1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 4, 4, 256)            0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 4, 4, 128)            32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 4, 4, 128)            512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 4, 4, 128)            0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 4, 4, 32)             36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 4, 4, 288)            0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 4, 4, 288)            1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 4, 4, 288)            0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 4, 4, 128)            36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 4, 4, 128)            512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 4, 4, 128)            0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 4, 4, 32)             36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 4, 4, 320)            0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 4, 4, 320)            1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 4, 4, 320)            0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 4, 4, 128)            40960     ['conv4_block3_0_relu[0][0]']
# ...
#  ormalization)
#
#  conv5_block10_0_relu (Acti  (None, 2, 2, 800)            0         ['conv5_block10_0_bn[0][0]']
#  vation)
#
#  conv5_block10_1_conv (Conv  (None, 2, 2, 128)            102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 2, 2, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 2, 2, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 2, 2, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 2, 2, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 2, 2, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 2, 2, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 2, 2, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 2, 2, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 2, 2, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 2, 2, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 2, 2, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 2, 2, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 2, 2, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 2, 2, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 2, 2, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 2, 2, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 2, 2, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 2, 2, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 2, 2, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 2, 2, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 2, 2, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 2, 2, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 2, 2, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 2, 2, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 2, 2, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 2, 2, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 2, 2, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 2, 2, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 2, 2, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 2, 2, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 2, 2, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 2, 2, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 2, 2, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 2, 2, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 2, 2, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 2, 2, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 2, 2, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 2, 2, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 2, 2, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 2, 2, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 2, 2, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 2, 2, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 2, 2, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 2, 2, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 2, 2, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 2, 2, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 2, 2, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 2, 2, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d (  (None, 1024)                 0         ['relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1024)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 3)                    3075      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7040579 (26.86 MB)
# Trainable params: 6873283 (26.22 MB)
# Non-trainable params: 167296 (653.50 KB)
# __________________________________________________________________________________________________

# %%
# QAT(Quantization Aware Training) 적용 준비
# QAT는 나중에 TFLite 양자화 모델로 바꿀 때 정확도 손실을 줄이기 위한 학습 방법입니다.
# 학습 중에 int8 양자화로 생길 오차를 미리 흉내 내면서 모델을 적응시킵니다.

# 선택적 양자화 함수
# 모든 layer를 양자화하지 않고, 주로 계산량이 큰 Dense와 Conv2D layer에만 표시합니다.
def apply_quantization_to_layer(layer):
    # Dense와 Conv2D 레이어만 양자화 대상이라고 표시합니다.
    if isinstance(layer, (keras.layers.Dense, keras.layers.Conv2D)):
        return tfmot.quantization.keras.quantize_annotate_layer(layer)

    # 나머지 layer는 그대로 둡니다.
    return layer

# 기존 model을 복제하면서 위 함수가 지정한 layer에 양자화 annotation을 붙입니다.
annotated_model = keras.models.clone_model(
    model,
    clone_function=apply_quantization_to_layer,
)

# annotation을 실제 QAT layer로 변환합니다.
# 이 결과가 학습에 사용할 qat_model입니다.
qat_model = tfmot.quantization.keras.quantize_apply(annotated_model)

# %%
# QAT가 적용된 모델 구조를 확인합니다.
# Conv2D나 Dense layer 주변에 QuantizeWrapperV2가 보이면 QAT 적용이 된 것입니다.
qat_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  tf.math.truediv (TFOpLambd  (None, 64, 64, 3)            0         ['input_1[0][0]']
#  a)
#
#  tf.nn.bias_add (TFOpLambda  (None, 64, 64, 3)            0         ['tf.math.truediv[1][0]']
#  )
#
#  tf.math.truediv_1 (TFOpLam  (None, 64, 64, 3)            0         ['tf.nn.bias_add[1][0]']
#  bda)
#
#  quant_zero_padding2d (Quan  (None, 70, 70, 3)            1         ['tf.math.truediv_1[1][0]']
#  tizeWrapperV2)
#
#  quant_conv1/conv (Quantize  (None, 32, 32, 64)           9539      ['quant_zero_padding2d[0][0]']
#  WrapperV2)
#
#  conv1/bn (BatchNormalizati  (None, 32, 32, 64)           256       ['quant_conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 32, 32, 64)           0         ['conv1/bn[1][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 34, 34, 64)           0         ['conv1/relu[1][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 16, 16, 64)           0         ['zero_padding2d_1[1][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 16, 16, 64)           256       ['pool1[1][0]']
#  rmalization)
#
#  quant_conv2_block1_0_relu   (None, 16, 16, 64)           3         ['conv2_block1_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block1_1_conv   (None, 16, 16, 128)          8451      ['quant_conv2_block1_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block1_1_bn (BatchNo  (None, 16, 16, 128)          512       ['quant_conv2_block1_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv2_block1_1_relu   (None, 16, 16, 128)          3         ['conv2_block1_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block1_2_conv   (None, 16, 16, 32)           36931     ['quant_conv2_block1_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block1_concat (Conca  (None, 16, 16, 96)           0         ['pool1[1][0]',
#  tenate)                                                             'quant_conv2_block1_2_conv[0]
#                                                                     [0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 16, 16, 96)           384       ['conv2_block1_concat[1][0]']
#  rmalization)
#
#  quant_conv2_block2_0_relu   (None, 16, 16, 96)           3         ['conv2_block2_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block2_1_conv   (None, 16, 16, 128)          12547     ['quant_conv2_block2_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block2_1_bn (BatchNo  (None, 16, 16, 128)          512       ['quant_conv2_block2_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv2_block2_1_relu   (None, 16, 16, 128)          3         ['conv2_block2_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block2_2_conv   (None, 16, 16, 32)           36931     ['quant_conv2_block2_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block2_concat (Conca  (None, 16, 16, 128)          0         ['conv2_block1_concat[1][0]',
#  tenate)                                                             'quant_conv2_block2_2_conv[0]
#                                                                     [0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 16, 16, 128)          512       ['conv2_block2_concat[1][0]']
#  rmalization)
#
#  quant_conv2_block3_0_relu   (None, 16, 16, 128)          3         ['conv2_block3_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block3_1_conv   (None, 16, 16, 128)          16643     ['quant_conv2_block3_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block3_1_bn (BatchNo  (None, 16, 16, 128)          512       ['quant_conv2_block3_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv2_block3_1_relu   (None, 16, 16, 128)          3         ['conv2_block3_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block3_2_conv   (None, 16, 16, 32)           36931     ['quant_conv2_block3_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block3_concat (Conca  (None, 16, 16, 160)          0         ['conv2_block2_concat[1][0]',
#  tenate)                                                             'quant_conv2_block3_2_conv[0]
#                                                                     [0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 16, 16, 160)          640       ['conv2_block3_concat[1][0]']
#  rmalization)
#
#  quant_conv2_block4_0_relu   (None, 16, 16, 160)          3         ['conv2_block4_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block4_1_conv   (None, 16, 16, 128)          20739     ['quant_conv2_block4_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block4_1_bn (BatchNo  (None, 16, 16, 128)          512       ['quant_conv2_block4_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv2_block4_1_relu   (None, 16, 16, 128)          3         ['conv2_block4_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block4_2_conv   (None, 16, 16, 32)           36931     ['quant_conv2_block4_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block4_concat (Conca  (None, 16, 16, 192)          0         ['conv2_block3_concat[1][0]',
#  tenate)                                                             'quant_conv2_block4_2_conv[0]
#                                                                     [0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 16, 16, 192)          768       ['conv2_block4_concat[1][0]']
#  rmalization)
#
#  quant_conv2_block5_0_relu   (None, 16, 16, 192)          3         ['conv2_block5_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block5_1_conv   (None, 16, 16, 128)          24835     ['quant_conv2_block5_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block5_1_bn (BatchNo  (None, 16, 16, 128)          512       ['quant_conv2_block5_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv2_block5_1_relu   (None, 16, 16, 128)          3         ['conv2_block5_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block5_2_conv   (None, 16, 16, 32)           36931     ['quant_conv2_block5_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block5_concat (Conca  (None, 16, 16, 224)          0         ['conv2_block4_concat[1][0]',
#  tenate)                                                             'quant_conv2_block5_2_conv[0]
#                                                                     [0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 16, 16, 224)          896       ['conv2_block5_concat[1][0]']
#  rmalization)
#
#  quant_conv2_block6_0_relu   (None, 16, 16, 224)          3         ['conv2_block6_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block6_1_conv   (None, 16, 16, 128)          28931     ['quant_conv2_block6_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block6_1_bn (BatchNo  (None, 16, 16, 128)          512       ['quant_conv2_block6_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv2_block6_1_relu   (None, 16, 16, 128)          3         ['conv2_block6_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv2_block6_2_conv   (None, 16, 16, 32)           36931     ['quant_conv2_block6_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv2_block6_concat (Conca  (None, 16, 16, 256)          0         ['conv2_block5_concat[1][0]',
#  tenate)                                                             'quant_conv2_block6_2_conv[0]
#                                                                     [0]']
#
#  pool2_bn (BatchNormalizati  (None, 16, 16, 256)          1024      ['conv2_block6_concat[1][0]']
#  on)
#
#  quant_pool2_relu (Quantize  (None, 16, 16, 256)          3         ['pool2_bn[1][0]']
#  WrapperV2)
#
#  quant_pool2_conv (Quantize  (None, 16, 16, 128)          33027     ['quant_pool2_relu[0][0]']
#  WrapperV2)
#
#  pool2_pool (AveragePooling  (None, 8, 8, 128)            0         ['quant_pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 8, 8, 128)            512       ['pool2_pool[1][0]']
#  rmalization)
#
#  quant_conv3_block1_0_relu   (None, 8, 8, 128)            3         ['conv3_block1_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block1_1_conv   (None, 8, 8, 128)            16643     ['quant_conv3_block1_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block1_1_bn (BatchNo  (None, 8, 8, 128)            512       ['quant_conv3_block1_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv3_block1_1_relu   (None, 8, 8, 128)            3         ['conv3_block1_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block1_2_conv   (None, 8, 8, 32)             36931     ['quant_conv3_block1_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block1_concat (Conca  (None, 8, 8, 160)            0         ['pool2_pool[1][0]',
#  tenate)                                                             'quant_conv3_block1_2_conv[0]
#                                                                     [0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 8, 8, 160)            640       ['conv3_block1_concat[1][0]']
#  rmalization)
#
#  quant_conv3_block2_0_relu   (None, 8, 8, 160)            3         ['conv3_block2_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block2_1_conv   (None, 8, 8, 128)            20739     ['quant_conv3_block2_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block2_1_bn (BatchNo  (None, 8, 8, 128)            512       ['quant_conv3_block2_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv3_block2_1_relu   (None, 8, 8, 128)            3         ['conv3_block2_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block2_2_conv   (None, 8, 8, 32)             36931     ['quant_conv3_block2_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block2_concat (Conca  (None, 8, 8, 192)            0         ['conv3_block1_concat[1][0]',
#  tenate)                                                             'quant_conv3_block2_2_conv[0]
#                                                                     [0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 8, 8, 192)            768       ['conv3_block2_concat[1][0]']
#  rmalization)
#
#  quant_conv3_block3_0_relu   (None, 8, 8, 192)            3         ['conv3_block3_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block3_1_conv   (None, 8, 8, 128)            24835     ['quant_conv3_block3_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block3_1_bn (BatchNo  (None, 8, 8, 128)            512       ['quant_conv3_block3_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv3_block3_1_relu   (None, 8, 8, 128)            3         ['conv3_block3_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block3_2_conv   (None, 8, 8, 32)             36931     ['quant_conv3_block3_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block3_concat (Conca  (None, 8, 8, 224)            0         ['conv3_block2_concat[1][0]',
#  tenate)                                                             'quant_conv3_block3_2_conv[0]
#                                                                     [0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 8, 8, 224)            896       ['conv3_block3_concat[1][0]']
#  rmalization)
#
#  quant_conv3_block4_0_relu   (None, 8, 8, 224)            3         ['conv3_block4_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block4_1_conv   (None, 8, 8, 128)            28931     ['quant_conv3_block4_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block4_1_bn (BatchNo  (None, 8, 8, 128)            512       ['quant_conv3_block4_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv3_block4_1_relu   (None, 8, 8, 128)            3         ['conv3_block4_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block4_2_conv   (None, 8, 8, 32)             36931     ['quant_conv3_block4_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block4_concat (Conca  (None, 8, 8, 256)            0         ['conv3_block3_concat[1][0]',
#  tenate)                                                             'quant_conv3_block4_2_conv[0]
#                                                                     [0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv3_block4_concat[1][0]']
#  rmalization)
#
#  quant_conv3_block5_0_relu   (None, 8, 8, 256)            3         ['conv3_block5_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block5_1_conv   (None, 8, 8, 128)            33027     ['quant_conv3_block5_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block5_1_bn (BatchNo  (None, 8, 8, 128)            512       ['quant_conv3_block5_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv3_block5_1_relu   (None, 8, 8, 128)            3         ['conv3_block5_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block5_2_conv   (None, 8, 8, 32)             36931     ['quant_conv3_block5_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block5_concat (Conca  (None, 8, 8, 288)            0         ['conv3_block4_concat[1][0]',
#  tenate)                                                             'quant_conv3_block5_2_conv[0]
#                                                                     [0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 8, 8, 288)            1152      ['conv3_block5_concat[1][0]']
#  rmalization)
#
#  quant_conv3_block6_0_relu   (None, 8, 8, 288)            3         ['conv3_block6_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block6_1_conv   (None, 8, 8, 128)            37123     ['quant_conv3_block6_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block6_1_bn (BatchNo  (None, 8, 8, 128)            512       ['quant_conv3_block6_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv3_block6_1_relu   (None, 8, 8, 128)            3         ['conv3_block6_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block6_2_conv   (None, 8, 8, 32)             36931     ['quant_conv3_block6_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block6_concat (Conca  (None, 8, 8, 320)            0         ['conv3_block5_concat[1][0]',
#  tenate)                                                             'quant_conv3_block6_2_conv[0]
#                                                                     [0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 8, 8, 320)            1280      ['conv3_block6_concat[1][0]']
#  rmalization)
#
#  quant_conv3_block7_0_relu   (None, 8, 8, 320)            3         ['conv3_block7_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block7_1_conv   (None, 8, 8, 128)            41219     ['quant_conv3_block7_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block7_1_bn (BatchNo  (None, 8, 8, 128)            512       ['quant_conv3_block7_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv3_block7_1_relu   (None, 8, 8, 128)            3         ['conv3_block7_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block7_2_conv   (None, 8, 8, 32)             36931     ['quant_conv3_block7_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block7_concat (Conca  (None, 8, 8, 352)            0         ['conv3_block6_concat[1][0]',
#  tenate)                                                             'quant_conv3_block7_2_conv[0]
#                                                                     [0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 8, 8, 352)            1408      ['conv3_block7_concat[1][0]']
#  rmalization)
#
#  quant_conv3_block8_0_relu   (None, 8, 8, 352)            3         ['conv3_block8_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block8_1_conv   (None, 8, 8, 128)            45315     ['quant_conv3_block8_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block8_1_bn (BatchNo  (None, 8, 8, 128)            512       ['quant_conv3_block8_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv3_block8_1_relu   (None, 8, 8, 128)            3         ['conv3_block8_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block8_2_conv   (None, 8, 8, 32)             36931     ['quant_conv3_block8_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block8_concat (Conca  (None, 8, 8, 384)            0         ['conv3_block7_concat[1][0]',
#  tenate)                                                             'quant_conv3_block8_2_conv[0]
#                                                                     [0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 8, 8, 384)            1536      ['conv3_block8_concat[1][0]']
#  rmalization)
#
#  quant_conv3_block9_0_relu   (None, 8, 8, 384)            3         ['conv3_block9_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block9_1_conv   (None, 8, 8, 128)            49411     ['quant_conv3_block9_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block9_1_bn (BatchNo  (None, 8, 8, 128)            512       ['quant_conv3_block9_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv3_block9_1_relu   (None, 8, 8, 128)            3         ['conv3_block9_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv3_block9_2_conv   (None, 8, 8, 32)             36931     ['quant_conv3_block9_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv3_block9_concat (Conca  (None, 8, 8, 416)            0         ['conv3_block8_concat[1][0]',
#  tenate)                                                             'quant_conv3_block9_2_conv[0]
#                                                                     [0]']
#
#  conv3_block10_0_bn (BatchN  (None, 8, 8, 416)            1664      ['conv3_block9_concat[1][0]']
#  ormalization)
#
#  quant_conv3_block10_0_relu  (None, 8, 8, 416)            3         ['conv3_block10_0_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv3_block10_1_conv  (None, 8, 8, 128)            53507     ['quant_conv3_block10_0_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv3_block10_1_bn (BatchN  (None, 8, 8, 128)            512       ['quant_conv3_block10_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv3_block10_1_relu  (None, 8, 8, 128)            3         ['conv3_block10_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv3_block10_2_conv  (None, 8, 8, 32)             36931     ['quant_conv3_block10_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv3_block10_concat (Conc  (None, 8, 8, 448)            0         ['conv3_block9_concat[1][0]',
#  atenate)                                                            'quant_conv3_block10_2_conv[0
#                                                                     ][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 8, 8, 448)            1792      ['conv3_block10_concat[1][0]']
#  ormalization)
#
#  quant_conv3_block11_0_relu  (None, 8, 8, 448)            3         ['conv3_block11_0_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv3_block11_1_conv  (None, 8, 8, 128)            57603     ['quant_conv3_block11_0_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv3_block11_1_bn (BatchN  (None, 8, 8, 128)            512       ['quant_conv3_block11_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv3_block11_1_relu  (None, 8, 8, 128)            3         ['conv3_block11_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv3_block11_2_conv  (None, 8, 8, 32)             36931     ['quant_conv3_block11_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv3_block11_concat (Conc  (None, 8, 8, 480)            0         ['conv3_block10_concat[1][0]',
#  atenate)                                                            'quant_conv3_block11_2_conv[0
#                                                                     ][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 8, 8, 480)            1920      ['conv3_block11_concat[1][0]']
#  ormalization)
#
#  quant_conv3_block12_0_relu  (None, 8, 8, 480)            3         ['conv3_block12_0_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv3_block12_1_conv  (None, 8, 8, 128)            61699     ['quant_conv3_block12_0_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv3_block12_1_bn (BatchN  (None, 8, 8, 128)            512       ['quant_conv3_block12_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv3_block12_1_relu  (None, 8, 8, 128)            3         ['conv3_block12_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv3_block12_2_conv  (None, 8, 8, 32)             36931     ['quant_conv3_block12_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv3_block12_concat (Conc  (None, 8, 8, 512)            0         ['conv3_block11_concat[1][0]',
#  atenate)                                                            'quant_conv3_block12_2_conv[0
#                                                                     ][0]']
#
#  pool3_bn (BatchNormalizati  (None, 8, 8, 512)            2048      ['conv3_block12_concat[1][0]']
#  on)
#
#  quant_pool3_relu (Quantize  (None, 8, 8, 512)            3         ['pool3_bn[1][0]']
#  WrapperV2)
#
#  quant_pool3_conv (Quantize  (None, 8, 8, 256)            131587    ['quant_pool3_relu[0][0]']
#  WrapperV2)
#
#  pool3_pool (AveragePooling  (None, 4, 4, 256)            0         ['quant_pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 4, 4, 256)            1024      ['pool3_pool[1][0]']
#  rmalization)
#
#  quant_conv4_block1_0_relu   (None, 4, 4, 256)            3         ['conv4_block1_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv4_block1_1_conv   (None, 4, 4, 128)            33027     ['quant_conv4_block1_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv4_block1_1_bn (BatchNo  (None, 4, 4, 128)            512       ['quant_conv4_block1_1_conv[0]
#  rmalization)                                                       [0]']
#
#  quant_conv4_block1_1_relu   (None, 4, 4, 128)            3         ['conv4_block1_1_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv4_block1_2_conv   (None, 4, 4, 32)             36931     ['quant_conv4_block1_1_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv4_block1_concat (Conca  (None, 4, 4, 288)            0         ['pool3_pool[1][0]',
#  tenate)                                                             'quant_conv4_block1_2_conv[0]
#                                                                     [0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 4, 4, 288)            1152      ['conv4_block1_concat[1][0]']
#  rmalization)
#
#  quant_conv4_block2_0_relu   (None, 4, 4, 288)            3         ['conv4_block2_0_bn[1][0]']
#  (QuantizeWrapperV2)
#
#  quant_conv4_block2_1_conv   (None, 4, 4, 128)            37123     ['quant_conv4_block2_0_relu[0]
#  (QuantizeWrapperV2)                                                [0]']
#
#  conv4_block2_1_bn (BatchNo  (None, 4, 4, 128)            512       ['quant_conv4_block2_1_conv[0]
#  rmalization)                                                       [0]']
#
# ...
#  conv5_block10_1_bn (BatchN  (None, 2, 2, 128)            512       ['quant_conv5_block10_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv5_block10_1_relu  (None, 2, 2, 128)            3         ['conv5_block10_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block10_2_conv  (None, 2, 2, 32)             36931     ['quant_conv5_block10_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block10_concat (Conc  (None, 2, 2, 832)            0         ['conv5_block9_concat[1][0]',
#  atenate)                                                            'quant_conv5_block10_2_conv[0
#                                                                     ][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 2, 2, 832)            3328      ['conv5_block10_concat[1][0]']
#  ormalization)
#
#  quant_conv5_block11_0_relu  (None, 2, 2, 832)            3         ['conv5_block11_0_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block11_1_conv  (None, 2, 2, 128)            106755    ['quant_conv5_block11_0_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block11_1_bn (BatchN  (None, 2, 2, 128)            512       ['quant_conv5_block11_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv5_block11_1_relu  (None, 2, 2, 128)            3         ['conv5_block11_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block11_2_conv  (None, 2, 2, 32)             36931     ['quant_conv5_block11_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block11_concat (Conc  (None, 2, 2, 864)            0         ['conv5_block10_concat[1][0]',
#  atenate)                                                            'quant_conv5_block11_2_conv[0
#                                                                     ][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 2, 2, 864)            3456      ['conv5_block11_concat[1][0]']
#  ormalization)
#
#  quant_conv5_block12_0_relu  (None, 2, 2, 864)            3         ['conv5_block12_0_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block12_1_conv  (None, 2, 2, 128)            110851    ['quant_conv5_block12_0_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block12_1_bn (BatchN  (None, 2, 2, 128)            512       ['quant_conv5_block12_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv5_block12_1_relu  (None, 2, 2, 128)            3         ['conv5_block12_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block12_2_conv  (None, 2, 2, 32)             36931     ['quant_conv5_block12_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block12_concat (Conc  (None, 2, 2, 896)            0         ['conv5_block11_concat[1][0]',
#  atenate)                                                            'quant_conv5_block12_2_conv[0
#                                                                     ][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 2, 2, 896)            3584      ['conv5_block12_concat[1][0]']
#  ormalization)
#
#  quant_conv5_block13_0_relu  (None, 2, 2, 896)            3         ['conv5_block13_0_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block13_1_conv  (None, 2, 2, 128)            114947    ['quant_conv5_block13_0_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block13_1_bn (BatchN  (None, 2, 2, 128)            512       ['quant_conv5_block13_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv5_block13_1_relu  (None, 2, 2, 128)            3         ['conv5_block13_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block13_2_conv  (None, 2, 2, 32)             36931     ['quant_conv5_block13_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block13_concat (Conc  (None, 2, 2, 928)            0         ['conv5_block12_concat[1][0]',
#  atenate)                                                            'quant_conv5_block13_2_conv[0
#                                                                     ][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 2, 2, 928)            3712      ['conv5_block13_concat[1][0]']
#  ormalization)
#
#  quant_conv5_block14_0_relu  (None, 2, 2, 928)            3         ['conv5_block14_0_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block14_1_conv  (None, 2, 2, 128)            119043    ['quant_conv5_block14_0_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block14_1_bn (BatchN  (None, 2, 2, 128)            512       ['quant_conv5_block14_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv5_block14_1_relu  (None, 2, 2, 128)            3         ['conv5_block14_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block14_2_conv  (None, 2, 2, 32)             36931     ['quant_conv5_block14_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block14_concat (Conc  (None, 2, 2, 960)            0         ['conv5_block13_concat[1][0]',
#  atenate)                                                            'quant_conv5_block14_2_conv[0
#                                                                     ][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 2, 2, 960)            3840      ['conv5_block14_concat[1][0]']
#  ormalization)
#
#  quant_conv5_block15_0_relu  (None, 2, 2, 960)            3         ['conv5_block15_0_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block15_1_conv  (None, 2, 2, 128)            123139    ['quant_conv5_block15_0_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block15_1_bn (BatchN  (None, 2, 2, 128)            512       ['quant_conv5_block15_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv5_block15_1_relu  (None, 2, 2, 128)            3         ['conv5_block15_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block15_2_conv  (None, 2, 2, 32)             36931     ['quant_conv5_block15_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block15_concat (Conc  (None, 2, 2, 992)            0         ['conv5_block14_concat[1][0]',
#  atenate)                                                            'quant_conv5_block15_2_conv[0
#                                                                     ][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 2, 2, 992)            3968      ['conv5_block15_concat[1][0]']
#  ormalization)
#
#  quant_conv5_block16_0_relu  (None, 2, 2, 992)            3         ['conv5_block16_0_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block16_1_conv  (None, 2, 2, 128)            127235    ['quant_conv5_block16_0_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block16_1_bn (BatchN  (None, 2, 2, 128)            512       ['quant_conv5_block16_1_conv[0
#  ormalization)                                                      ][0]']
#
#  quant_conv5_block16_1_relu  (None, 2, 2, 128)            3         ['conv5_block16_1_bn[1][0]']
#   (QuantizeWrapperV2)
#
#  quant_conv5_block16_2_conv  (None, 2, 2, 32)             36931     ['quant_conv5_block16_1_relu[0
#   (QuantizeWrapperV2)                                               ][0]']
#
#  conv5_block16_concat (Conc  (None, 2, 2, 1024)           0         ['conv5_block15_concat[1][0]',
#  atenate)                                                            'quant_conv5_block16_2_conv[0
#                                                                     ][0]']
#
#  bn (BatchNormalization)     (None, 2, 2, 1024)           4096      ['conv5_block16_concat[1][0]']
#
#  relu (Activation)           (None, 2, 2, 1024)           0         ['bn[1][0]']
#
#  global_average_pooling2d (  (None, 1024)                 0         ['relu[1][0]']
#  GlobalAveragePooling2D)
#
#  quant_dropout (QuantizeWra  (None, 1024)                 1         ['global_average_pooling2d[1][
#  pperV2)                                                            0]']
#
#  quant_dense (QuantizeWrapp  (None, 3)                    3080      ['quant_dropout[0][0]']
#  erV2)
#
# ==================================================================================================
# Total params: 7061783 (26.94 MB)
# Trainable params: 6873283 (26.22 MB)
# Non-trainable params: 188500 (736.33 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### 모델 컴파일

# %%
# 모델 학습 설정
# optimizer: Adam 사용
# learning_rate=1e-5: 사전학습 모델을 미세조정하므로 학습률을 작게 둡니다.
# loss: sparse_categorical_crossentropy
#   라벨이 one-hot이 아니라 0, 1, 2 정수이기 때문에 sparse 버전을 사용합니다.
# metrics: accuracy로 정확도를 확인합니다.
qat_model.compile(optimizer= keras.optimizers.Adam(learning_rate=1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### 학습 전 상황

# %%
# 예측 결과를 눈으로 확인하기 위한 함수입니다.
# 테스트 이미지 10장을 골라 실제 라벨과 모델 예측값을 제목에 표시합니다.
def Make_Result_Plot(suptitle, data, label, y_max):
    # 테스트 데이터를 10개 구간으로 나누어 대표 이미지를 하나씩 봅니다.
    size = data.shape[0]//10

    # 2행 5열 그림판을 만듭니다.
    fig_result, ax_result = plt.subplots(2,5,figsize=(18, 7))
    fig_result.suptitle(suptitle)

    for idx in range(10):
        cnt = idx * size + size//2

        # 이미지 출력
        ax_result[idx//5,idx%5].imshow(data[cnt].reshape((IMG_SIZE,IMG_SIZE, 3)))

        # label: 실제 정답, y: 모델 예측값
        ax_result[idx//5,idx%5].set_title(
            "test_data[{}] (label : {} / y : {})".format(cnt, label[cnt], y_max[cnt])
        )

# %%
# 학습 전 모델의 예측 상태를 확인합니다.
# 아직 RPS 데이터에 맞게 충분히 학습되지 않았기 때문에 틀리는 예측이 많을 수 있습니다.
y_out = qat_model.predict(test_data)

# softmax 출력 3개 중 가장 큰 값의 위치를 예측 클래스로 선택합니다.
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))

# 학습 전 예측 결과를 그림으로 확인합니다.
Make_Result_Plot("Before Training", test_data, test_labels, y_max)
# Out:
# 18/18 [==============================] - 8s 161ms/step

# %% [markdown]
# ### 콜백 설정

# %%
# 학습 중 가장 성능이 좋은 모델을 저장하기 위한 설정입니다.
# h5 파일에는 QAT가 적용된 Keras 모델이 저장됩니다.
savedModelName = 'RPS_PreTrained_DenseNet_Augmentation_QAT.h5'

callbacks = [
    # save_best_only=True: 검증 성능이 가장 좋을 때만 저장합니다.
    keras.callbacks.ModelCheckpoint(savedModelName,
                                    save_best_only=True)
]

# %% [markdown]
# ### 모델 학습

# %%
# %%time
# 모델 학습
# train_gen은 ImageDataGenerator가 만든 변형 이미지를 계속 공급합니다.
# epochs=10은 전체 학습 데이터를 10번 반복해서 본다는 뜻입니다.
# validation_data는 학습에 쓰지 않은 test_data로 성능을 확인합니다.
history = qat_model.fit(train_gen, epochs=10,
                    callbacks=callbacks,
                    validation_data=(test_data, test_labels))
# Out:
# Epoch 1/10
# I0000 00:00:1780891327.776789 3293545 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
# 68/68 [==============================] - ETA: 0s - loss: 1.1052 - accuracy: 0.5778
# /home/mvpserver23/miniconda3/envs/semiai/lib/python3.11/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 68/68 [==============================] - 84s 799ms/step - loss: 1.1052 - accuracy: 0.5778 - val_loss: 0.3824 - val_accuracy: 0.8569
# Epoch 2/10
# 68/68 [==============================] - 52s 764ms/step - loss: 0.4799 - accuracy: 0.8080 - val_loss: 0.2107 - val_accuracy: 0.9248
# Epoch 3/10
# 68/68 [==============================] - 50s 742ms/step - loss: 0.2881 - accuracy: 0.8872 - val_loss: 0.1410 - val_accuracy: 0.9468
# Epoch 4/10
# 68/68 [==============================] - 52s 770ms/step - loss: 0.2031 - accuracy: 0.9263 - val_loss: 0.1027 - val_accuracy: 0.9633
# Epoch 5/10
# 68/68 [==============================] - 50s 741ms/step - loss: 0.1310 - accuracy: 0.9530 - val_loss: 0.0629 - val_accuracy: 0.9743
# Epoch 6/10
# 68/68 [==============================] - 46s 674ms/step - loss: 0.1167 - accuracy: 0.9632 - val_loss: 0.0708 - val_accuracy: 0.9725
# Epoch 7/10
# 68/68 [==============================] - 49s 719ms/step - loss: 0.0833 - accuracy: 0.9696 - val_loss: 0.0293 - val_accuracy: 0.9872
# Epoch 8/10
# 68/68 [==============================] - 46s 681ms/step - loss: 0.0795 - accuracy: 0.9747 - val_loss: 0.0334 - val_accuracy: 0.9798
# Epoch 9/10
# 68/68 [==============================] - 48s 710ms/step - loss: 0.0717 - accuracy: 0.9751 - val_loss: 0.0259 - val_accuracy: 0.9908
# Epoch 10/10
# 68/68 [==============================] - 47s 686ms/step - loss: 0.0459 - accuracy: 0.9848 - val_loss: 0.0385 - val_accuracy: 0.9872
# CPU times: user 1h 2min 30s, sys: 23min 9s, total: 1h 25min 39s
# Wall time: 8min 45s

# %% [markdown]
# > ### Ploting : Cost/Training Count

# %%
# 학습 과정 시각화
# 위 그래프: 정확도 변화
# 아래 그래프: 손실(loss) 변화
# train과 validation이 함께 좋아지면 학습이 잘 되고 있는 것입니다.

plt.figure(figsize=(6, 10))

# 정확도 그래프
plt.subplot(2, 1, 1)
plt.title('Accuray')
plt.plot(history.history['accuracy'], 'b', label='train_accuracy')
plt.plot(history.history['val_accuracy'], 'g', label='val_accuracy')
# plt.ylim([0,1])
plt.grid(True)
plt.ylabel('Accuracy')
plt.legend(loc='best')

# 손실 그래프
plt.subplot(2, 1, 2)
plt.title('Loss')
plt.plot(history.history['loss'], 'b', label='train_loss')
plt.plot(history.history['val_loss'], 'g', label='val_loss')
# plt.ylim([0,5])
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### best 모델 로딩 및 테스트

# %%
# 저장된 best 모델 다시 불러오기
# QAT 모델에는 QuantizeWrapperV2 같은 특수 layer가 들어 있습니다.
# 그래서 일반 load_model이 아니라 quantize_scope 안에서 불러와야 합니다.
from tensorflow_model_optimization.quantization.keras import quantize_scope

try:
    # quantize_scope() 안에서 모델을 로드하면 QAT 관련 사용자 정의 객체를 인식합니다.
    with quantize_scope():
        model_best = keras.models.load_model(savedModelName)
except ValueError as e:
    print(f"Model load failed: {e}")

# %%
# 학습 후 best 모델의 예측 결과를 확인합니다.
y_out = model_best.predict(test_data)
y_max = np.argmax(y_out, axis=1).reshape((-1, 1))
Make_Result_Plot("After Training", test_data, test_labels, y_max)
# Out:
# 18/18 [==============================] - 7s 166ms/step

# %% [markdown]
# ### best 모델 백업

# %%
# 학습된 모델과 TFLite 파일을 저장할 위치를 정합니다.
# 학생용 저장소에서는 results/ 폴더에 결과를 저장합니다.
# results/는 .gitignore에 들어 있으므로 큰 모델 파일이 실수로 push되지 않습니다.
from pathlib import Path

try:
    repo_root = get_git_root()
except NameError:
    repo_root = None

if repo_root is None:
    repo_root = Path.cwd()

save_dir = str(repo_root / "results") + "/"
Path(save_dir).mkdir(parents=True, exist_ok=True)
print("save_dir:", save_dir)
# Out:
# save_dir: /SSD1/sjchoi/semiai/RP2-RPS-QAT-Lab/results/

# %%
# 학습된 best Keras 모델(.h5)을 results/ 폴더로 복사합니다.
# results/는 .gitignore에 포함되어 있어 GitHub에는 올라가지 않습니다.
import shutil
from pathlib import Path

src_model = Path(savedModelName)
dst_model = Path(save_dir) / savedModelName

if src_model.exists():
    shutil.copy2(src_model, dst_model)
    print("Saved best model to:", dst_model)
else:
    print("Model file not found:", src_model)
# Out:
# Saved best model to: /SSD1/sjchoi/semiai/RP2-RPS-QAT-Lab/results/RPS_PreTrained_DenseNet_Augmentation_QAT.h5

# %% [markdown]
# ### 초보자 핵심 정리
#
# 여기까지의 핵심은 다음과 같습니다.
#
# 1. `RPS_Dataset`에서 가위/바위/보 이미지를 읽어 `64 x 64 x 3` 배열로 만듭니다.
# 2. ImageNet으로 미리 학습된 `DenseNet121`을 가져와 마지막 분류기를 3개 클래스로 바꿉니다.
# 3. 데이터 보강으로 조명, 위치, 회전, 크기 변화에 강하게 만듭니다.
# 4. QAT를 적용해 TFLite 양자화 후에도 정확도가 유지되도록 학습합니다.
# 5. 최종 `.tflite` 파일을 라즈베리파이에 복사해 실시간 손 모양 인식에 사용합니다.

# %% [markdown]
# ### LiteRT 모델로 변환

# %%
# Keras QAT 모델을 TFLite 모델로 변환합니다.
# TFLite는 라즈베리파이 같은 엣지 장치에서 실행하기 좋은 모델 형식입니다.
converter = tf.lite.TFLiteConverter.from_keras_model(model_best)

# Optimize.DEFAULT는 기본 양자화/최적화를 적용하라는 뜻입니다.
# QAT로 학습했기 때문에 양자화 후 정확도 손실을 줄이는 데 도움이 됩니다.
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# 실제 변환 실행. 결과는 bytes 형태의 tflite_model입니다.
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp_bug4336/assets
# INFO:tensorflow:Assets written to: /tmp/tmp_bug4336/assets
# /home/mvpserver23/miniconda3/envs/semiai/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1780891963.872063 3293545 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1780891963.872092 3293545 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1780891963.872462 3293545 reader.cc:83] Reading SavedModel from: /tmp/tmp_bug4336
# I0000 00:00:1780891964.018686 3293545 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1780891964.019025 3293545 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp_bug4336
# I0000 00:00:1780891964.779605 3293545 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# I0000 00:00:1780891964.972056 3293545 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1780891968.435466 3293545 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp_bug4336
# I0000 00:00:1780891969.539136 3293545 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 5667143 microseconds.
# I0000 00:00:1780891970.774901 3293545 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %% [markdown]
# ### LiteRT 모델을 파일로 저장

# %%
# 라즈베리파이에 가져갈 최종 TFLite 파일 이름입니다.
# 이 파일을 Raspberry Pi에서 tflite_runtime 또는 LiteRT로 실행합니다.
tfliteFileName = 'RPS_PreTrained_DenseNet_Augmentation_QAT.tflite'

# %%
# 변환된 TFLite 모델을 파일로 저장합니다.
# 저장 결과가 약 7.7MB 정도라면 정상적으로 만들어진 것입니다.
open(save_dir + tfliteFileName, 'wb').write(tflite_model)
# Out:
# 7720736
